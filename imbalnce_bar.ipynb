# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime
import mplfinance as mpf
from fast_ewma import _ewma
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\outof\Desktop\afml\imbalnce_bar.ipynb 셀 1 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/outof/Desktop/afml/imbalnce_bar.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> from datetime import datetime
#       <a href='vscode-notebook-cell:/c%3A/Users/outof/Desktop/afml/imbalnce_bar.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a> import mplfinance as mpf
# ----> <a href='vscode-notebook-cell:/c%3A/Users/outof/Desktop/afml/imbalnce_bar.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a> from fast_ewma import _ewma
#
# ImportError: cannot import name '_ewma' from 'fast_ewma' (c:\Users\outof\Desktop\afml\fast_ewma.py)

# %%
def signed_tick(tick, initial_value=1.0):
    diff = tick['priceclose'] - tick['priceclose'].shift(1)
    return (abs(diff) / diff).ffill().fillna(initial_value)

# %%
df = pd.read_csv("Future_tick_101T3.csv")
df = df[df['logdate'] >= 20221218]
df = df.drop(['Unnamed: 0'],axis=1)

# %%
df['signed_tick'] = signed_tick(df)
df.iloc[50:60]
# Out:
#      logdate  logtime stockcode   priceopen   pricehigh    pricelow  \
# 50  20221220     1415     101T3  302.000000  302.000000  302.000000
# 51  20221220     1415     101T3  302.000000  302.000000  302.000000
# 52  20221220     1415     101T3  302.000000  302.000000  302.000000
# 53  20221220     1415     101T3  302.000000  302.000000  302.000000
# 54  20221220     1415     101T3  302.000000  302.000000  302.000000
# 55  20221220     1415     101T3  302.000000  302.000000  302.000000
# 56  20221220     1415     101T3  302.049988  302.049988  302.049988
# 57  20221220     1415     101T3  302.000000  302.000000  302.000000
# 58  20221220     1415     101T3  302.000000  302.000000  302.000000
# 59  20221220     1415     101T3  302.000000  302.000000  302.000000
#
#     priceclose  volume  signed_tick
# 50  302.000000       1          1.0
# 51  302.000000      26          1.0
# 52  302.000000       1          1.0
# 53  302.000000       1          1.0
# ...
